# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
os.chdir("C:\\Users\\Vivian.Lisanza\\Downloads") #moving csv file to the correct directory
pima = pd.read_csv("diabetes.csv")

# %%
pima.tail(10) #shows the last 10 records of the dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76             20       79  37.5
# 759            6      190             92             20       79  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31       79  44.0
# 762            9       89             62             20       79  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27       79  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             20       79  30.1
# 767            1       93             70             31       79  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
total_columns=len(pima.axes[1]) 
print(total_columns) #prints out the number of columns
# Out:
# 9

# %%
pima.head(10) #shows the first ten records of the dataset
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0            6      148             72             35       79  33.600000
# 1            1       85             66             29       79  26.600000
# 2            8      183             64             20       79  23.300000
# 3            1       89             66             23       94  28.100000
# 4            0      137             40             35      168  43.100000
# 5            5      116             74             20       79  25.600000
# 6            3       78             50             32       88  31.000000
# 7           10      115             69             20       79  35.300000
# 8            2      197             70             45      543  30.500000
# 9            8      125             96             20       79  31.992578
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# ...

# %%
pima.ndim #the dimension of the data set
# Out:
# 2

# %%
pima.size #the size
# Out:
# 6912

# %%
pima.dtypes #prints out datatypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
pima.isnull().values.any() #missing values are not a part of the datset. Therefore,
                            #no, there aren't any missing values
# Out:
# False

# %%
pima.iloc[:,0:8].describe()
#the summary statistics tells us information about the dataset. For instance, the pregnancy column goes into detail about the count, mean, standard deviation and so forth
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.675781      72.250000      26.447917  118.270833
# std       3.369578   30.436252      12.117203       9.733872   93.243829
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.000000   79.000000
# 50%       3.000000  117.000000      72.000000      23.000000   79.000000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    32.450805                  0.471876   33.240885
# std      6.875374                  0.331329   11.760232
# min     18.200000                  0.078000   21.000000
# ...

# %%
sns.displot(pima['BloodPressure'], kind='kde')
plt.show()
#density reaches 0.035 as blood pressure increases and then it stabilizes out
#displot shows the relationship between blood presure and density

# %%
pima[pima['Glucose']==pima['Glucose'].max()]['BMI']
# Out:
# 661    42.9
# Name: BMI, dtype: float64

# %%
m1 = pima['BMI'].mean()  # calculates mean
print(m1)
m2 = pima['BMI'].median()  # calculates median
print(m2)
m3 = pima['BMI'].mode()[0]  # calculates mode
print(m3)
#the three measuresthe mean of central tendency are not equal due to there being a different value for
# Out:
# 32.45080515543617
# 32.0
# 32.0

# %%
pima[pima['Glucose']>pima['Glucose'].mean()].shape[0] #womens glucose levels that are above the mean level of glucose
# Out:
# 343

# %%
pima[(pima['BloodPressure']==pima['BloodPressure'].median()) & (pima['BMI']<pima['BMI'].median())]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 14             5      166             72             19      175  25.8
# 93             4      134             72             20       79  23.8
# 103            1       81             72             18       40  26.6
# 205            5      111             72             28       79  23.9
# 299            8      112             72             20       79  23.6
# 325            1      157             72             21      168  25.6
# 330            8      118             72             19       79  23.1
# 366            6      124             72             20       79  27.6
# 380            1      107             72             30       82  30.8
# 393            4      116             72             12       87  22.1
# 406            4      115             72             20       79  28.9
# 446            1      100             72             12       70  25.3
# ...

# %%
sns.pairplot(data=pima,vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
plt.show()
#observations:in all data sets there are some correlation due to the blue and
#orange overlapping

# %%
sns.scatterplot(x='Glucose',y='Insulin',data=pima)
plt.show()
#observations: positive scatterplot from left to right
#there are some outliers as the glucose levels increase
#strong positive linear relationship

# %%
plt.boxplot(pima['Age'])
plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()
#yes, there are outliers

# %%
plt.hist(pima[pima['Outcome']==1]['Age'], bins = 5)
plt.title('Distribution of Age for Women who has Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
#histogram shows the range of women who have diabetes based on their age group.
#The younger the women, the higher the frequency

# %%
plt.hist(pima[pima['Outcome']==0]['Age'], bins = 5)
plt.title('Distribution of Age for Women who do not have Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
#histogram shows the range of women who dont have diabetse
#around early 20s is a spike, decreases with age

# %%
Q1 = pima.quantile(0.25)
Q3 = pima.quantile(0.75)
IQR = 0.75 - 0.25
print(IQR)
#IQR is used to assess the variability of where most of the values lie
#a boxplot visualizes the same
# Out:
# 0.5

# %%
correlation_matrix = pima.iloc[:,0:8]
correlation_matrix
#there is a relationship between the dataset values of pima
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35       79  33.6
# 1              1       85             66             29       79  26.6
# 2              8      183             64             20       79  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27       79  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             20       79  30.1
# 767            1       93             70             31       79  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(correlation_matrix, annot = True)

plt.show()
